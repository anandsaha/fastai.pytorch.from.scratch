# %% [markdown]
# Reference: https://arxiv.org/pdf/1506.01186.pdf

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
num_iterations = 6000
stepsize = 1000
base_lr = 0.0001
max_lr = 0.001

# %%
lr_trend = list()
cycle_trend = list()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn']

# %%
def get_triangular_lr(iteration, stepsize, base_lr, max_lr):
    cycle = np.floor(1 + iteration/(2  * stepsize))
    x = np.abs(iteration/stepsize - 2 * cycle + 1)
    lr = base_lr + (max_lr - base_lr) * np.maximum(0, (1-x))
    return lr

# %%
for iteration in range(num_iterations):
    lr = get_triangular_lr(iteration, stepsize, base_lr, max_lr)
    lr_trend.append(lr)

# %%
for iteration in range(num_iterations):
    cycle = np.floor(1 + iteration/(2  * stepsize))
    x = np.abs(iteration/stepsize - 2 * cycle + 1)
    lr = base_lr + (max_lr - base_lr) * np.maximum(0, (1-x))
    lr_trend.append(lr)
    cycle_trend.append(cycle)

# %%
plt.style.use('seaborn-pastel')
plt.plot(lr_trend)
plt.xlabel('Iterations')
plt.ylabel('Learning Rate')
# Out:
# Text(0,0.5,'Learning Rate')

# %%
plt.plot(cycle_trend)
